# %% [markdown]
# <a href="https://colab.research.google.com/github/SonaJaiswal/jpmc_pages/blob/main/exp_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#PRAC 9 
# A) Using Python OpenCV library , open an image 
import cv2 as cv 
from google.colab.patches import cv2_imshow 
 
image = cv2.imread('pics.png' , 1 ) 
cv2_imshow(image)
# Out:
# <PIL.Image.Image image mode=RGB size=500x667 at 0x7F6779182890>

# %%
#PRAC 9
# B) Using Python OpenCV library , retrive the size of an image 
dimensions = image.shape
print(dimensions)
# Out:
# (667, 500, 3)

# %%
#PRAC 9
# C) Using Python OpenCV library , resize an image 
half = cv2.resize(image, (0, 0), fx = 0.1, fy = 0.1)
bigger = cv2.resize(image, (1050, 1610))
stretch_near = cv2.resize(image, (780, 540),interpolation = cv2.INTER_NEAREST)
 
Titles =["Original", "Half", "Bigger", "Interpolation Nearest"]

images =[image, half, bigger, stretch_near]
count = 4
 
for i in range(count):
    plt.subplot(2, 2, i + 1)
    plt.title(Titles[i])
    plt.imshow(images[i])
 
plt.show()

# %%
#PRAC 10
# A) Using Python OpenCV library , crop an image 
cropped_image = image[80:280, 150:330]
crop_dim = cropped_image.shape 
print(crop_dim)
cv2_imshow(cropped_image)
# Out:
# (200, 180, 3)
# <PIL.Image.Image image mode=RGB size=180x200 at 0x7F6779245790>

# %%
#PRAC 10
# B) Using Python OpenCV library , rotate an image 
res_image = cv2.rotate(image, cv2.cv2.ROTATE_90_CLOCKWISE)
cv2_imshow(res_image)
# Out:
# <PIL.Image.Image image mode=RGB size=667x500 at 0x7F67791B9910>
